# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import all csv files and check the headers

#1st allocation done to ratings of the movie

ratings = pd.read_csv('rating.csv')
ratings.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
rating = ratings.drop(['timestamp'], axis=1)
rating.head()
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %%
#2nd allocation done to movie

movie_titles = pd.read_csv('movie.csv')
movie_titles.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
new_ratings = pd.merge(movie_titles,rating, on='movieId')
new_ratings
# Out:
#           movieId                                              title  \
# 0               1                                   Toy Story (1995)
# 1               1                                   Toy Story (1995)
# 2               1                                   Toy Story (1995)
# 3               1                                   Toy Story (1995)
# 4               1                                   Toy Story (1995)
# 5               1                                   Toy Story (1995)
# 6               1                                   Toy Story (1995)
# 7               1                                   Toy Story (1995)
# 8               1                                   Toy Story (1995)
# 9               1                                   Toy Story (1995)
# 10              1                                   Toy Story (1995)
# 11              1                                   Toy Story (1995)
# 12              1                                   Toy Story (1995)
# ...

# %%
updated_ratings = new_ratings.drop(['genres'], axis=1)
updated_ratings.head()
# Out:
#    movieId             title  userId  rating
# 0        1  Toy Story (1995)       3     4.0
# 1        1  Toy Story (1995)       6     5.0
# 2        1  Toy Story (1995)       8     4.0
# 3        1  Toy Story (1995)      10     4.0
# 4        1  Toy Story (1995)      11     4.5

# %%
sample_set = updated_ratings.sample(n=50000)
sample_set.head()
# Out:
#           movieId                                    title  userId  rating
# 19995304   118702                          Unbroken (2014)   17378     3.0
# 19915294   104520  Crimson Permanent Assurance, The (1983)   23180     3.5
# 17904810    32587                          Sin City (2005)   16088     5.0
# 6116174      1193   One Flew Over the Cuckoo's Nest (1975)   82251     4.5
# 15396198     5039                      Dragonslayer (1981)   44898     3.0

# %%
user_ratings = sample_set.pivot_table(index=['userId'],columns=['title'],values='rating')
user_ratings.head()
# Out:
# title   $9.99 (2008)  'Round Midnight (1986)  'burbs, The (1989)  \
# userId
# 7                NaN                     NaN                 NaN
# 11               NaN                     NaN                 NaN
# 14               NaN                     NaN                 NaN
# 21               NaN                     NaN                 NaN
# 22               NaN                     NaN                 NaN
#
# title   'night Mother (1986)  (500) Days of Summer (2009)  \
# userId
# 7                        NaN                          NaN
# 11                       NaN                          NaN
# 14                       NaN                          NaN
# 21                       NaN                          NaN
# 22                       NaN                          NaN
#
# title   *batteries not included (1987)  \
# userId
# 7                                  NaN
# 11                                 NaN
# 14                                 NaN
# ...

# %%
corrMatrix = user_ratings.corr(method='pearson', min_periods=5)
corrMatrix.head()

# %%
newest = updated_ratings.groupby('userId')
newest.head(5)
# Out:
#           movieId                                              title  userId  \
# 0               1                                   Toy Story (1995)       3
# 1               1                                   Toy Story (1995)       6
# 2               1                                   Toy Story (1995)       8
# 3               1                                   Toy Story (1995)      10
# 4               1                                   Toy Story (1995)      11
# 5               1                                   Toy Story (1995)      12
# 6               1                                   Toy Story (1995)      13
# 7               1                                   Toy Story (1995)      14
# 8               1                                   Toy Story (1995)      16
# 9               1                                   Toy Story (1995)      19
# 10              1                                   Toy Story (1995)      22
# ...

# %%
corrMatrix = newest.corr(method='pearson', min_periods=1000)
corrMatrix.head(10)
# Out:
#                 movieId  rating
# userId
# 1      movieId      NaN     NaN
#        rating       NaN     NaN
# 2      movieId      NaN     NaN
#        rating       NaN     NaN
# 3      movieId      NaN     NaN
#        rating       NaN     NaN
# 4      movieId      NaN     NaN
#        rating       NaN     NaN
# 5      movieId      NaN     NaN
#        rating       NaN     NaN

# %%
myRatings = corrMatrix.dropna()
myRatings
# Out:
#                  movieId    rating
# userId
# 116    movieId  1.000000  0.138420
#        rating   0.138420  1.000000
# 156    movieId  1.000000 -0.086833
#        rating  -0.086833  1.000000
# 208    movieId  1.000000 -0.079431
#        rating  -0.079431  1.000000
# 298    movieId  1.000000 -0.058824
#        rating  -0.058824  1.000000
# 359    movieId  1.000000 -0.062839
#        rating  -0.062839  1.000000
# 394    movieId  1.000000  0.037716
#        rating   0.037716  1.000000
# 572    movieId  1.000000 -0.042902
#        rating  -0.042902  1.000000
# 586    movieId  1.000000  0.172076
#        rating   0.172076  1.000000
# 614    movieId  1.000000  0.139775
#        rating   0.139775  1.000000
# 632    movieId  1.000000  0.037731
#        rating   0.037731  1.000000
# 741    movieId  1.000000 -0.071151
#        rating  -0.071151  1.000000
# 768    movieId  1.000000 -0.085922
#        rating  -0.085922  1.000000
# 775    movieId  1.000000 -0.036889
# ...

# %%
#Take sample size to evaluation
sample_ratings = verynew_ratings.sample(n=10000)
sample_ratings.head(5)
# Out:
#           movieId                                title  userId  rating
# 8757401      1747                   Wag the Dog (1997)   40117     2.0
# 1796004       269  My Crazy Life (Mi vida loca) (1993)  122656     3.0
# 9519755      2023      Godfather: Part III, The (1990)   24047     3.5
# 17157946     7460         Coffee and Cigarettes (2003)   79229     2.5
# 11030438     2571                   Matrix, The (1999)   37910     5.0

# %%
sample_ratings.shape
# Out:
# (10000, 4)

# %%
user_ratings = sample_ratings.pivot_table(index=['userId'],columns=['title'],values=['rating'])
user_ratings.sort_values('userId')
user_ratings.head(300)
# Out:
#                    rating                              \
# title  'burbs, The (1989) (500) Days of Summer (2009)
# userId
# 1                     NaN                         NaN
# 7                     NaN                         NaN
# 31                    NaN                         NaN
# 48                    NaN                         NaN
# 54                    NaN                         NaN
# 56                    NaN                         NaN
# 73                    NaN                         NaN
# 91                    NaN                         NaN
# 95                    NaN                         NaN
# 96                    NaN                         NaN
# 99                    NaN                         NaN
# 110                   NaN                         NaN
# 142                   NaN                         NaN
# 144                   NaN                         NaN
# 147                   NaN                         NaN
# ...

# %%
corrMatrix = user_ratings.corr(method='pearson', min_periods=100)
corrMatrix.head()
# Out:
#                                                      rating  \
# title                                    'burbs, The (1989)
#        title
# rating 'burbs, The (1989)                               NaN
#        (500) Days of Summer (2009)                      NaN
#        *batteries not included (1987)                   NaN
#        10 Items or Less (2006)                          NaN
#        10 Things I Hate About You (1999)                NaN
#
#                                                                       \
# title                                    (500) Days of Summer (2009)
#        title
# rating 'burbs, The (1989)                                        NaN
#        (500) Days of Summer (2009)                               NaN
#        *batteries not included (1987)                            NaN
#        10 Items or Less (2006)                                   NaN
#        10 Things I Hate About You (1999)                         NaN
#
# ...

# %%
#3rd allocation done to link

Id_link = pd.read_csv('link.csv')
Id_link.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
#4th allocation done to genome tags

genome_tags = pd.read_csv('genome_tags.csv')
genome_tags.head()
# Out:
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
# 3      4         1920s
# 4      5         1930s

# %%
#5th allocation done to genome scores

genome_scores = pd.read_csv('genome_scores.csv')
genome_scores.head()
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02500
# 1        1      2    0.02500
# 2        1      3    0.05775
# 3        1      4    0.09675
# 4        1      5    0.14675

# %%
movie_titles.groupby('title')['rating'].count().sort_values(ascending=False).head(10)
# Out:
# title
# Pulp Fiction (1994)                          67310
# Forrest Gump (1994)                          66172
# Shawshank Redemption, The (1994)             63366
# Silence of the Lambs, The (1991)             63299
# Jurassic Park (1993)                         59715
# Star Wars: Episode IV - A New Hope (1977)    54502
# Braveheart (1995)                            53769
# Terminator 2: Judgment Day (1991)            52244
# Matrix, The (1999)                           51334
# Schindler's List (1993)                      50054
# Name: rating, dtype: int64

# %%
movie_titles.groupby('title')['rating'].mean().sort_values(ascending=False).head(10)
# Out:
# title
# Codes of Gender, The (2010)                    5.0
# Poison (1951)                                  5.0
# Barchester Chronicles, The (1982)              5.0
# Prom Queen: The Marc Hall Story (2004)         5.0
# Argentina latente (2007)                       5.0
# Ella Lola, a la Trilby (1898)                  5.0
# Iran Is Not the Problem (2008)                 5.0
# Pretty Things (2001)                           5.0
# Blue Swallow (Cheong yeon) (2005)              5.0
# Precision: The Measure of All Things (2013)    5.0
# Name: rating, dtype: float64

# %%
rating = pd.DataFrame(movie_titles.groupby('title')['rating'].mean())
rating.head()
# Out:
#                                                       rating
# title
# #chicagoGirl: The Social Network Takes on a Dic...  3.666667
# $ (Dollars) (1971)                                  2.833333
# $5 a Day (2008)                                     2.871795
# $9.99 (2008)                                        3.009091
# $ellebrity (Sellebrity) (2012)                      2.000000

# %%
rating['num of ratings'] = pd.DataFrame(movie_titles.groupby('title')['rating'].count())
rating.head()
# Out:
#                                                       rating  num of ratings
# title
# #chicagoGirl: The Social Network Takes on a Dic...  3.666667               3
# $ (Dollars) (1971)                                  2.833333              24
# $5 a Day (2008)                                     2.871795              39
# $9.99 (2008)                                        3.009091              55
# $ellebrity (Sellebrity) (2012)                      2.000000               2

# %%
plt.figure(figsize=(10,5))
rating['num of ratings'].hist(bins=70)

# %%
plt.figure(figsize=(10,4))
rating['rating'].hist(bins=70)

# %%
sns.jointplot(x='rating',y='num of ratings',data=rating,alpha=0.5)
